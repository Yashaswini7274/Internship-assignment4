# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
train_images = train_images.reshape((60000, 28*28)) / 255.0
test_images = test_images.reshape((10000, 28*28)) / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
plt.figure(figsize=(10, 5))
for i in range(20):
    plt.subplot(4, 5, i+1)
    plt.imshow(train_images[i].reshape(28, 28), cmap='gray')
    plt.title(f"Label: {train_labels[i]}")
    plt.axis('off')
plt.suptitle('Sample MNIST Images with Labels', y=1.02)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.hist(train_labels, bins=10, rwidth=0.8, alpha=0.7)
plt.xticks(range(10))
plt.title('Distribution of Labels in Training Set')
plt.xlabel('Digit Class')
plt.ylabel('Count')
plt.grid(axis='y', alpha=0.3)
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout

model = Sequential([
    Dense(784, activation='tanh', input_shape=(28*28,)),
    BatchNormalization(),
    Dropout(0.25),

    Dense(392, activation='tanh'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(196, activation='tanh'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='tanh'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(10, activation='softmax')  # Output layer
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(train_images, train_labels, epochs=15, batch_size=128,
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 36ms/step - accuracy: 0.8297 - loss: 0.5653 - val_accuracy: 0.9468 - val_loss: 0.1743
# Epoch 2/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.9330 - loss: 0.2267 - val_accuracy: 0.9597 - val_loss: 0.1276
# Epoch 3/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 16s 35ms/step - accuracy: 0.9495 - loss: 0.1715 - val_accuracy: 0.9669 - val_loss: 0.1129
# Epoch 4/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - accuracy: 0.9590 - loss: 0.1388 - val_accuracy: 0.9706 - val_loss: 0.0961
# Epoch 5/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 34ms/step - accuracy: 0.9654 - loss: 0.1147 - val_accuracy: 0.9742 - val_loss: 0.0913
# Epoch 6/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.9696 - loss: 0.1018 - val_accuracy: 0.9749 - val_loss: 0.0863
# Epoch 7/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.9734 - loss: 0.0888 - val_accuracy: 0.9784 - val_loss: 0.0785
# Epoch 8/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 16s 35ms/step - accuracy: 0.9750 - loss: 0.0815 - val_accuracy: 0.9789 - val_loss: 0.0746
# Epoch 9/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 21s 35ms/step - accuracy: 0.9795 - loss: 0.0674 - val_accuracy: 0.9809 - val_loss: 0.0702
# Epoch 10/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.9797 - loss: 0.0661 - val_accuracy: 0.9803 - val_loss: 0.0689
# Epoch 11/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - accuracy: 0.9822 - loss: 0.0578 - val_accuracy: 0.9819 - val_loss: 0.0677
# Epoch 12/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 21s 36ms/step - accuracy: 0.9836 - loss: 0.0552 - val_accuracy: 0.9808 - val_loss: 0.0694
# Epoch 13/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - accuracy: 0.9834 - loss: 0.0532 - val_accuracy: 0.9816 - val_loss: 0.0650
# Epoch 14/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 16s 34ms/step - accuracy: 0.9843 - loss: 0.0503 - val_accuracy: 0.9795 - val_loss: 0.0741
# Epoch 15/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.9864 - loss: 0.0442 - val_accuracy: 0.9807 - val_loss: 0.0724

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"\nTest accuracy: {test_acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9772 - loss: 0.0898
#
# Test accuracy: 0.9807

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 10))

# Create a list of 10 digit classes
unique_digits = list(range(10))

# Track how many of each digit we've shown
count_per_digit = {digit: 0 for digit in unique_digits}
max_count_per_digit = 2  # Show 2 examples per digit (2 x 10 = 20 total)

shown = 0
i = 0
while shown < 25 and i < len(test_images):
    true_label = test_labels[i]
    if count_per_digit[true_label] < max_count_per_digit:
        plt.subplot(5, 5, shown + 1)
        plt.imshow(test_images[i].reshape(28, 28), cmap='gray')

        pred_label = np.argmax(model.predict(test_images[i:i+1]))
        color = 'green' if pred_label == true_label else 'red'
        plt.title(f"Pred: {pred_label}\nTrue: {true_label}", color=color)
        plt.axis('off')

        count_per_digit[true_label] += 1
        shown += 1
    i += 1

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
